# %%
import pandas as pd
import os

# %%
CSV_METADATA_FILE_NAME = "metadata.csv"
DATASET_METADATA_DIR = "US8K"
DATASET_DIR_NAME = f"{DATASET_METADATA_DIR}_transformed"
CUTOFF = 8192
# CUTOFF = 16384

# %%
project_dir = os.path.relpath(os.path.join(os.getcwd(), os.pardir))

csv_metadata_path = os.path.join(project_dir, "metadata", DATASET_METADATA_DIR, CSV_METADATA_FILE_NAME)

# %%
df = pd.read_csv(csv_metadata_path)
df.head()
# Out:
#             name extension                                               path  \
# 0   100852-0-0-0       wav  C:\users\user\studia\audio_clustering_autoenco...
# 1   100852-0-0-1       wav  C:\users\user\studia\audio_clustering_autoenco...
# 2  100852-0-0-10       wav  C:\users\user\studia\audio_clustering_autoenco...
# 3  100852-0-0-11       wav  C:\users\user\studia\audio_clustering_autoenco...
# 4  100852-0-0-12       wav  C:\users\user\studia\audio_clustering_autoenco...
#
#               dirs
# 0  air_conditioner
# 1  air_conditioner
# 2  air_conditioner
# 3  air_conditioner
# 4  air_conditioner

# %%
import librosa
from scipy import signal
import soundfile as sf

# %%
metadata_dir = os.path.join(project_dir, "metadata")

dataset_metadata_dir = os.path.join(metadata_dir, DATASET_METADATA_DIR)
os.makedirs(DATASET_DIR_NAME, exist_ok=True)

csv_file_name = "metadata_transformed.csv"
csv_file_path = os.path.join(dataset_metadata_dir, csv_file_name)

# %%
datasets_dir = os.path.join(project_dir, "datasets")

dataset_dir = os.path.join(datasets_dir, DATASET_DIR_NAME)
os.makedirs(dataset_dir, exist_ok=True)

# %%
def load_audio_from_path(path):
    sample_rate = librosa.get_samplerate(path)
    if sample_rate < 22050:
        sample_rate = 22050
    return librosa.load(path, sr=sample_rate)


def get_output_file(parent_dirs, file_name):
    if parent_dirs != '':
        return f"{dataset_dir}\\{parent_dirs}\\{file_name}.wav"
    
    return f"{dataset_dir}\\{file_name}\\{name}.wav"


# Filter audio file for given cutoff (for example to work in range 0kHz - 8kHz)
def low_pass_filter(y, sr, index, cutoff=CUTOFF):
    # Cutoff frequency (default = 8 kHz)
    cutoff_hz = cutoff

    # Low-pass filter
    nyquist = 0.5 * sr
    if not (0 < cutoff_hz < nyquist):
        print(f"sr: {sr}")
        print(f"index: {index}")
        raise ValueError(f"cutoff_hz must be between 0 and {nyquist}. Got {cutoff_hz}.")
        
    normal_cutoff = cutoff_hz / nyquist
    b, a = signal.butter(8, normal_cutoff, btype='low', analog=False)

    # Apply the filter to the audio data
    filtered_audio = signal.filtfilt(b, a, y)
    return filtered_audio

# %%
df_copy = df.copy()
df_copy['path'] = ''
df_copy['extension'] = 'wav'

for index, row in df.iterrows():
    name = row['name']
    path = row['path']    
    parent_dirs = row['dirs']
    
    y, sr = load_audio_from_path(path)
    output_file = get_output_file(parent_dirs, name)
    
    filtered_audio = low_pass_filter(y, sr, index, CUTOFF)
    
    try:
        os.makedirs(os.path.dirname(output_file), exist_ok=True)
    except Exception as e:
        print("Error creating directory:", e)
        
    sf.write(output_file, filtered_audio, sr, format='WAV')
    
    absolute_path = os.path.abspath(output_file)
    df_copy.at[index, 'path'] = absolute_path
    
    if index % 50 == 0:
        print(f"Transformed {index} files")
        

df_copy.to_csv(csv_file_path, index=False)
# Out:
# Transformed 0 files
# Transformed 50 files
# Transformed 100 files
# Transformed 150 files
# Transformed 200 files
# Transformed 250 files
# Transformed 300 files
# Transformed 350 files
# Transformed 400 files
# Transformed 450 files
# Transformed 500 files
# Transformed 550 files
# Transformed 600 files
# Transformed 650 files
# Transformed 700 files
# Transformed 750 files
# Transformed 800 files
# Transformed 850 files
# Transformed 900 files
# Transformed 950 files
# Transformed 1000 files
# Transformed 1050 files
# Transformed 1100 files
# Transformed 1150 files
# Transformed 1200 files
# Transformed 1250 files
# Transformed 1300 files
# Transformed 1350 files
# Transformed 1400 files
# Transformed 1450 files
# Transformed 1500 files
# Transformed 1550 files
# Transformed 1600 files
# Transformed 1650 files
# Transformed 1700 files
# Transformed 1750 files
# Transformed 1800 files
# Transformed 1850 files
# Transformed 1900 files
# Transformed 1950 files
# Transformed 2000 files
# Transformed 2050 files
# Transformed 2100 files
# Transformed 2150 files
# Transformed 2200 files
# Transformed 2250 files
# Transformed 2300 files
# Transformed 2350 files
# Transformed 2400 files
# Transformed 2450 files
# Transformed 2500 files
# Transformed 2550 files
# Transformed 2600 files
# Transformed 2650 files
# Transformed 2700 files
# Transformed 2750 files
# Transformed 2800 files
# Transformed 2850 files
# Transformed 2900 files
# Transformed 2950 files
# Transformed 3000 files
# Transformed 3050 files
# Transformed 3100 files
# Transformed 3150 files
# Transformed 3200 files
# Transformed 3250 files
# Transformed 3300 files
# Transformed 3350 files
# Transformed 3400 files
# Transformed 3450 files
# Transformed 3500 files
# Transformed 3550 files
# Transformed 3600 files
# Transformed 3650 files
# Transformed 3700 files
# Transformed 3750 files
# Transformed 3800 files
# Transformed 3850 files
# Transformed 3900 files
# Transformed 3950 files
# Transformed 4000 files
# Transformed 4050 files
# Transformed 4100 files
# Transformed 4150 files
# Transformed 4200 files
# Transformed 4250 files
# Transformed 4300 files
# Transformed 4350 files
# Transformed 4400 files
# Transformed 4450 files
# Transformed 4500 files
# Transformed 4550 files
# Transformed 4600 files
# Transformed 4650 files
# Transformed 4700 files
# Transformed 4750 files
# Transformed 4800 files
# Transformed 4850 files
# Transformed 4900 files
# Transformed 4950 files
# Transformed 5000 files
# Transformed 5050 files
# Transformed 5100 files
# Transformed 5150 files
# Transformed 5200 files
# Transformed 5250 files
# Transformed 5300 files
# Transformed 5350 files
# Transformed 5400 files
# Transformed 5450 files
# Transformed 5500 files
# Transformed 5550 files
# Transformed 5600 files
# Transformed 5650 files
# Transformed 5700 files
# Transformed 5750 files
# Transformed 5800 files
# Transformed 5850 files
# Transformed 5900 files
# Transformed 5950 files
# Transformed 6000 files
# Transformed 6050 files
# Transformed 6100 files
# Transformed 6150 files
# Transformed 6200 files
# Transformed 6250 files
# Transformed 6300 files
# Transformed 6350 files
# Transformed 6400 files
# Transformed 6450 files
# Transformed 6500 files
# Transformed 6550 files
# Transformed 6600 files
# Transformed 6650 files
# Transformed 6700 files
# Transformed 6750 files
# Transformed 6800 files
# Transformed 6850 files
# Transformed 6900 files
# Transformed 6950 files
# Transformed 7000 files
# Transformed 7050 files
# Transformed 7100 files
# Transformed 7150 files
# Transformed 7200 files
# Transformed 7250 files
# Transformed 7300 files
# Transformed 7350 files
# Transformed 7400 files
# Transformed 7450 files
# Transformed 7500 files
# Transformed 7550 files
# Transformed 7600 files
# Transformed 7650 files
# Transformed 7700 files
# Transformed 7750 files
# Transformed 7800 files
# Transformed 7850 files
# Transformed 7900 files
# Transformed 7950 files
# Transformed 8000 files
# Transformed 8050 files
# Transformed 8100 files
# Transformed 8150 files
# Transformed 8200 files
# Transformed 8250 files
# Transformed 8300 files
# Transformed 8350 files
# Transformed 8400 files
# Transformed 8450 files
# Transformed 8500 files
# Transformed 8550 files
# Transformed 8600 files
# Transformed 8650 files
# Transformed 8700 files
