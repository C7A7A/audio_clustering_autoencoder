# %% [markdown]
# ## Read data to to dataframe

# %%
import os
import pandas as pd

# %%
project_dir = os.path.abspath(os.path.join(os.getcwd(), os.pardir))

#TODO: argument for csv file name
csv_file_name = "music_metadata.csv"
csv_file_path = os.path.join(project_dir, "metadata", csv_file_name)

# %%
df = pd.read_csv(csv_file_path)
df.head()
# Out:
#                              name extension  \
# 0              50_Minutes-Colours       mp3
# 1            50_Minutes-Nightwalk       mp3
# 2       50_Minutes-The_Great_Wall       mp3
# 3  Abigail_Lapell-Dress_Rehearsal       mp3
# 4        Albino_Catfish-Ice_Cream       mp3
#
#                                                 path
# 0  C:\users\user\studia\audio_clustering_autoenco...
# 1  C:\users\user\studia\audio_clustering_autoenco...
# 2  C:\users\user\studia\audio_clustering_autoenco...
# 3  C:\users\user\studia\audio_clustering_autoenco...
# 4  C:\users\user\studia\audio_clustering_autoenco...

# %% [markdown]
# ## Retrieve features

# %%
import IPython.display as ipd
import librosa
import matplotlib
import matplotlib.pyplot as plt
from itertools import cycle

# %%
matplotlib.use('Agg')

color_pal = plt.rcParams["axes.prop_cycle"].by_key()["color"]
color_cycle = cycle(plt.rcParams["axes.prop_cycle"].by_key()["color"])

AUDIO_ID = 0
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_17964\1798829608.py:1: MatplotlibDeprecationWarning: Auto-close()ing of figures upon backend switching is deprecated since 3.8 and will be removed two minor releases later.  To suppress this warning, explicitly call plt.close('all') first.
#   matplotlib.use('TkAgg')

# %%
def get_audio(df, id):
    file_path = df.loc[id, 'path']
    return ipd.Audio(filename=file_path)


def display_audio(file):
    ipd.display(file)


def load_audio(df, id):
    file_path = df.loc[id, 'path']
    return librosa.load(file_path)

# %%
audio = get_audio(df, AUDIO_ID)
display_audio(audio)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#TODO: check is sample rate is ok
y, sr = load_audio(df, AUDIO_ID)
print(f"audio data (first 20): {y[:20]}")
print(f"audio data shape: {y.shape}")
print(f"sample rate: {sr}")
# Out:
# audio data (first 20): [ 3.1664968e-08  7.4505806e-09 -3.7252903e-09  0.0000000e+00
#  -9.3132257e-10 -1.1175871e-08 -4.6566129e-09 -1.9557774e-08
#   9.3132257e-10 -4.6566129e-09 -2.6077032e-08 -3.7252903e-09
#  -4.6566129e-09  1.3969839e-09 -1.0244548e-08 -2.6077032e-08
#  -9.3132257e-10 -1.1175871e-08 -2.7939677e-08 -2.0489097e-08]
# audio data shape: (221760,)
# sample rate: 22050
# C:\Users\User\AppData\Local\Temp\ipykernel_17964\1686257282.py:12: UserWarning: PySoundFile failed. Trying audioread instead.
#   return librosa.load(file_path)

# %%
def plot_raw_audio(y):
    fig, ax = plt.subplots(figsize=(12, 5))
    pd.Series(y).plot(
        ax=ax,
        lw=1,
        title="Raw Audio",
        color=color_pal[0]
    )
    return fig

# %%
figure = plot_raw_audio(y)
plt.show()
